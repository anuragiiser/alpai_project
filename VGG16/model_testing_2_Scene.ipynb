# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"  # Disable GPU

import tensorflow as tf
print("Running on CPU:", tf.config.list_physical_devices('GPU'))
# Out:
# 2025-04-09 16:35:30.261809: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-09 16:35:30.274895: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744216530.289434  189844 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744216530.293827  189844 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1744216530.305051  189844 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1744216530.305063  189844 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1744216530.305065  189844 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1744216530.305066  189844 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-04-09 16:35:30.308927: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Running on CPU: []
# 2025-04-09 16:35:32.845632: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2025-04-09 16:35:32.845657: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:167] env: CUDA_VISIBLE_DEVICES="-1"
# 2025-04-09 16:35:32.845662: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:170] CUDA_VISIBLE_DEVICES is set to -1 - this hides all GPUs from CUDA
# 2025-04-09 16:35:32.845666: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:178] verbose logging is disabled. Rerun with verbose logging (usually --v=1 or --vmodule=cuda_diagnostics=1) to get more diagnostic output from this module
# 2025-04-09 16:35:32.845671: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:183] retrieving CUDA diagnostic information for host: hela
# 2025-04-09 16:35:32.845673: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:190] hostname: hela
# 2025-04-09 16:35:32.845776: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:197] libcuda reported version is: 550.120.0
# 2025-04-09 16:35:32.845791: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:201] kernel reported version is: 550.120.0
# 2025-04-09 16:35:32.845793: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:291] kernel version seems to match DSO: 550.120.0

# %%
import numpy as np
import os

X_test = np.load( "/home/sombit-ng-nonadm/vaibhav_intern_pg/BTP+AIproject/Task_1_scene_level/task1_X_test.npy")
y_test = np.load("/home/sombit-ng-nonadm/vaibhav_intern_pg/BTP+AIproject/Task_1_scene_level/task1_y_test.npy")
print(X_test.shape)
print(y_test.shape)
# Out:
# (2997, 224, 224, 3)
# (2997, 3)

# %%
from tensorflow.keras.models import load_model

# Load model without compiling (since you're only using it for prediction)
model = load_model(
    "/home/sombit-ng-nonadm/vaibhav_intern_pg/BTP+AIproject/VGG16/Models/vgg16_modelScene_small_final.h5",
    compile=False
)

# %%
predictions = model.predict(X_test)
predicted_classes = np.argmax(predictions, axis=1)

print(predicted_classes[:10])
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 52s 547ms/step
# [1 0 2 2 2 0 2 2 0 2]

# %%
y_test_labels = np.argmax(y_test, axis=1)

# %%
import numpy as np
from sklearn.metrics import accuracy_score, classification_report

# Convert model predictions to class labels
y_pred_labels_labelled = np.argmax(predictions, axis=1)
# Now compute accuracy
test_accuracy_labelled = accuracy_score(y_test_labels, y_pred_labels_labelled)
report_labelled= classification_report(y_test_labels, y_pred_labels_labelled, target_names=['Class 0', 'Class 1','Class 2'], output_dict=True)
print(report_labelled)
print(f"Test Accuracy: {test_accuracy_labelled:.4f}")
print(f"macro avg f1-score: {report_labelled['macro avg']['f1-score']:.4f}")
# Out:
# {'Class 0': {'precision': 0.6130653266331658, 'recall': 0.25363825363825365, 'f1-score': 0.35882352941176476, 'support': 962}, 'Class 1': {'precision': 0.9504132231404959, 'recall': 0.5958549222797928, 'f1-score': 0.732484076433121, 'support': 965}, 'Class 2': {'precision': 0.5361083249749248, 'recall': 0.9990654205607477, 'f1-score': 0.697780678851175, 'support': 1070}, 'accuracy': 0.6299632966299633, 'macro avg': {'precision': 0.6998622915828622, 'recall': 0.6161861988262647, 'f1-score': 0.5963627615653536, 'support': 2997}, 'weighted avg': {'precision': 0.6942120494744255, 'recall': 0.6299632966299633, 'f1-score': 0.6001537188598054, 'support': 2997}}
# Test Accuracy: 0.6300
# macro avg f1-score: 0.5964
